# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn

# %%
df = pd.read_csv("costsensitiveregression.csv")
df
# Out:
#         NotCount  YesCount  ATPM      PFD      PFG  SFD      SFG         WP  \
# 0              2        21   0.0  0.00000  0.00000  0.0   0.0000   0.000000
# 1             23         0   0.0  0.04400  0.00000  0.0   0.0000   0.306179
# 2              1        22   0.0  0.00000  0.00000  0.0   0.0000   0.000000
# 3              5        18   0.0  0.00000  0.00000  0.0   0.0000   0.000000
# 4              1        22   0.0  0.00000  0.00000  0.0   0.0000   0.000000
# ...          ...       ...   ...      ...      ...  ...      ...        ...
# 147631         4        19   1.0  1.09306  4.25256  0.0   0.0000  21.946737
# 147632        16         7   1.0  0.00000  0.00000  0.0   0.0000   0.000000
# 147633         2        21   1.0  4.64145  5.47616  0.0  25.5783  48.283019
# 147634         3        20   1.0  0.00000  0.40989  0.0   0.0000   0.694601
# 147635         6        17   1.0  3.16026  4.86214  0.0   0.0000  19.958639
#
#               WS   AH   AN  Status           FNC
# ...

# %%
df.columns
# Out:
# Index(['NotCount', 'YesCount', 'ATPM', 'PFD', 'PFG', 'SFD', 'SFG', 'WP', 'WS',
#        'AH', 'AN', 'Status', 'FNC'],
#       dtype='object')

# %%
X_data = df[['NotCount', 'YesCount', 'ATPM', 'PFD', 'PFG', 'SFD', 'SFG', 'WP', 'WS',
       'AH', 'AN',]]
X_data
# Out:
#         NotCount  YesCount  ATPM      PFD      PFG  SFD      SFG         WP  \
# 0              2        21   0.0  0.00000  0.00000  0.0   0.0000   0.000000
# 1             23         0   0.0  0.04400  0.00000  0.0   0.0000   0.306179
# 2              1        22   0.0  0.00000  0.00000  0.0   0.0000   0.000000
# 3              5        18   0.0  0.00000  0.00000  0.0   0.0000   0.000000
# 4              1        22   0.0  0.00000  0.00000  0.0   0.0000   0.000000
# ...          ...       ...   ...      ...      ...  ...      ...        ...
# 147631         4        19   1.0  1.09306  4.25256  0.0   0.0000  21.946737
# 147632        16         7   1.0  0.00000  0.00000  0.0   0.0000   0.000000
# 147633         2        21   1.0  4.64145  5.47616  0.0  25.5783  48.283019
# 147634         3        20   1.0  0.00000  0.40989  0.0   0.0000   0.694601
# 147635         6        17   1.0  3.16026  4.86214  0.0   0.0000  19.958639
#
#               WS   AH   AN
# 0       0.000000  0.0  0.0
# ...

# %%
Y_data = df[['Status']]
Y_data
# Out:
#         Status
# 0            0
# 1            1
# 2            0
# 3            1
# 4            0
# ...        ...
# 147631       0
# 147632       0
# 147633       0
# 147634       0
# 147635       0
#
# [147636 rows x 1 columns]

# %%
class CostSensitiveRegression(nn.Module):

    def __init__(self , input_dim , output_dim , epochs):
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.epochs = epochs

    def forward
# Out:
#   File "/var/folders/x0/r7576wrd5w3dfxhxvxn3v81w0000gn/T/ipykernel_21282/2466701253.py", line 8
#     def forward
#                ^
# SyntaxError: invalid syntax
